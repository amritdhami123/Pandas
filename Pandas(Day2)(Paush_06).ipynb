# %%
# import pandass 
import pandas as pd

# %%
# import data 
data = pd.read_csv(r"E:\python 1 pm\stats_for_data_analysis\cars_data_updated.csv")

# %%
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %% [markdown]
# # Explore

# %%
# columns ()  it returns the name of columns in dataset
data.columns
# Out:
# Index(['location', 'year', 'run', 'fuel_type', 'trans', 'owner', 'mileage',
#        'engine', 'power', 'seats', 'new_price', 'price', 'brand', 'model'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   7253 non-null   object
#  1   year       7253 non-null   int64
#  2   run        7253 non-null   int64
#  3   fuel_type  7253 non-null   object
#  4   trans      7253 non-null   object
#  5   owner      7253 non-null   object
#  6   mileage    7251 non-null   float64
#  7   engine     7207 non-null   float64
#  8   power      7078 non-null   float64
#  9   seats      7200 non-null   float64
#  10  new_price  1006 non-null   object
#  11  price      6019 non-null   float64
#  12  brand      7253 non-null   object
#  13  model      7253 non-null   object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 793.4+ KB

# %%
data
# Out:
#         location  year    run fuel_type      trans   owner  mileage  engine  \
# 0         Mumbai  2010  72000       CNG     Manual   First    26.60   998.0
# 1           Pune  2015  41000    Diesel     Manual   First    19.67  1582.0
# 2        Chennai  2011  46000    Petrol     Manual   First    18.20  1199.0
# 3        Chennai  2012  87000    Diesel     Manual   First    20.77  1248.0
# 4     Coimbatore  2013  40670    Diesel  Automatic  Second    15.20  1968.0
# ...          ...   ...    ...       ...        ...     ...      ...     ...
# 7248   Hyderabad  2011  89411    Diesel     Manual   First    20.54  1598.0
# 7249      Mumbai  2015  59000    Petrol  Automatic   First    17.21  1197.0
# 7250     Kolkata  2012  28000    Diesel     Manual   First    23.08  1461.0
# 7251        Pune  2013  52262    Petrol  Automatic   Third    17.20  1197.0
# 7252       Kochi  2014  72443    Diesel  Automatic   First    10.00  2148.0
#
# ...

# %%
# unique() , it returns the unique values in a column in form list 
# find all the unique brands 
data.brand.unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini', 'Hindustan', 'OpelCorsa'], dtype=object)

# %%
# nunique() , it count the number of unique values in a dataframe 
# count the number of unique brands in the dataframe 
data.brand.nunique()
# Out:
# 33

# %%
# valuecount(), it counts the frequency of each item in a column of a dataframe 
data.brand.value_counts()
# Out:
# brand
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            507
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          331
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land               67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini               31
# Volvo              28
# Jeep               19
# Porsche            19
# Datsun             17
# Force               3
# ISUZU               3
# Isuzu               2
# Bentley             2
# Smart               1
# Ambassador          1
# Lamborghini         1
# Hindustan           1
# OpelCorsa           1
# Name: count, dtype: int64

# %%
# max() , it returns the maximum value in a columm 
# find the maximum value of mileage 
data.mileage.max()
# Out:
# np.float64(33.54)

# %%
# min() , it returns the minimum values in a column
# find the minimum value of mileage 
data.mileage.min()
# Out:
# np.float64(0.0)

# %%
# mean() it returns the mean value in a column
# find the mean value of mileage 
data.mileage.mean()
# Out:
# np.float64(18.141580471659083)

# %%
# median() it returns the median value in a column 
data.mileage.median()
# Out:
# np.float64(18.16)

# %%
# mode() it returns the most frequent item in a column 
# find the mode value of mileage 
data.mileage.mode()
# Out:
# 0    17.0
# Name: mileage, dtype: float64

# %%
data.model.mode()
# Out:
# 0    Swift
# Name: model, dtype: object

# %%
# highest selling brand 
data.brand.mode()
# Out:
# 0    Maruti
# Name: brand, dtype: object

# %%
data.year.mode()
# Out:
# 0    2015
# Name: year, dtype: int64

# %%
# std() , it returns the standard deviation 
# find the standard deviation of mileage 
data.mileage.std()
# Out:
# np.float64(4.562196601725892)

# %%
# aggerated function , ie agg() functiopm 
data[['mileage','power']].agg(['min', 'max', 'mean'])
# Out:
#        mileage       power
# min    0.00000   34.200000
# max   33.54000  616.000000
# mean  18.14158  112.765214

# %%
# quantile() , it returans quantile value or it also returns percentiles of given columns 
# find first quartilne(0.25) of mileage 
data.mileage.quantile(0.25)
# Out:
# np.float64(15.17)

# %%
# sort() / sortby()

# %%
data.sort_values(by=['location']) # sorts data by location , in ascending order by default
# Out:
#        location  year    run fuel_type      trans   owner  mileage  engine  \
# 6663  Ahmedabad  2014  84004    Diesel  Automatic   First    20.38  1968.0
# 6984  Ahmedabad  2015  71588    Diesel     Manual   First    27.39  1248.0
# 5755  Ahmedabad  2008  51000    Petrol     Manual   First    17.00  1086.0
# 2260  Ahmedabad  2012  95000    Diesel  Automatic  Second    22.48  1995.0
# 4247  Ahmedabad  2012  75000    Diesel  Automatic  Second    12.39  2179.0
# ...         ...   ...    ...       ...        ...     ...      ...     ...
# 2905       Pune  2011  95995    Diesel  Automatic   First    18.48  1995.0
# 5309       Pune  2009  75000    Petrol     Manual  Second    14.70  1150.0
# 5308       Pune  2013  74000    Petrol     Manual   First    22.00  1197.0
# 5338       Pune  2012  55000    Petrol  Automatic  Second    15.00  1396.0
# 4422       Pune  2014  90000    Petrol     Manual  Second    20.36  1197.0
#
#        power  seats   new_price  price      brand   model
# ...

# %%
data.sort_values(by=['location'], ascending=False) # sorts the data by location in descending order
# Out:
#        location  year     run fuel_type      trans   owner  mileage  engine  \
# 1414       Pune  2012   65000    Diesel     Manual   First    22.30  1248.0
# 6323       Pune  2011   75000    Petrol     Manual   First    18.50  1197.0
# 3959       Pune  2016   64000    Petrol  Automatic   First    23.10   998.0
# 4829       Pune  2014   71000    Diesel     Manual  Second    25.80  1498.0
# 2142       Pune  2012  100000    Petrol     Manual   First    20.92   998.0
# ...         ...   ...     ...       ...        ...     ...      ...     ...
# 2388  Ahmedabad  2013   40000    Petrol     Manual   First    17.00  1197.0
# 6655  Ahmedabad  2012   50000    Diesel  Automatic  Second    14.21  2143.0
# 7071  Ahmedabad  2009   90000    Petrol     Manual   First    18.50  1197.0
# 2998  Ahmedabad  2014   78616    Diesel  Automatic  Second    14.84  2143.0
# 5492  Ahmedabad  2012   50123    Diesel     Manual   First    17.00  1405.0
#
# ...

# %%
data.sort_values(by=['location', 'year'])
# Out:
#        location  year    run fuel_type      trans   owner  mileage  engine  \
# 1318  Ahmedabad  2002  85000    Petrol     Manual   First    13.00  1343.0
# 3200  Ahmedabad  2004  60000    Petrol     Manual  Second    17.30  1061.0
# 3061  Ahmedabad  2005  58000    Petrol     Manual  Second     0.00   999.0
# 5843  Ahmedabad  2005  81000    Petrol     Manual  Second    15.90  1298.0
# 194   Ahmedabad  2007  60006    Petrol     Manual   First     0.00     NaN
# ...         ...   ...    ...       ...        ...     ...      ...     ...
# 5940       Pune  2018  27000    Diesel     Manual   First    28.40  1248.0
# 5941       Pune  2018   1000    Petrol     Manual   First    25.17   799.0
# 6155       Pune  2018  24001    Diesel  Automatic   First    13.60  1999.0
# 5339       Pune  2019   1000    Petrol     Manual   First    17.19  1197.0
# 6529       Pune  2019   1015    Petrol  Automatic   First    19.00  1199.0
#
#        power  seats   new_price  price    brand   model
# ...

# %%
# Sort Values Column wise 
list_columns = data.columns.to_list()

# %%
list_columns= sorted(list_columns)

# %%
df = data.copy()

# %%
df.columns=df.columns(list_columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.columns=df.columns(list_columns)
#
# TypeError: 'Index' object is not callable

# %%
df.columns = list_columns

# %%
df.head(2)
# Out:
#     brand  engine  fuel_type location mileage  model  new_price   owner  \
# 0  Mumbai    2010      72000      CNG  Manual  First      26.60   998.0
# 1    Pune    2015      41000   Diesel  Manual  First      19.67  1582.0
#
#     power  price  run  seats    trans   year
# 0   58.16    5.0  NaN   1.75   Maruti  Wagon
# 1  126.20    5.0  NaN  12.50  Hyundai  Creta

# %%
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %% [markdown]
# <h1> <b> Data Cleaning with Pandas </h1> </b>

# %% [markdown]
# <h2> <b> Renaming , Adding and Dropping Columns </b> </h2>

# %%
data.columns
# Out:
# Index(['location', 'year', 'run', 'fuel_type', 'trans', 'owner', 'mileage',
#        'engine', 'power', 'seats', 'new_price', 'price', 'brand', 'model'],
#       dtype='object')

# %%
# rename a single column 
data.rename(columns = {'fuel_type':'FUEL'}, inplace=True)

# %%
data.head(2)
# Out:
#   location  year    run    FUEL   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000     CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000  Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %%
data.head(2)
# Out:
#   location  year    run    FUEL   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000     CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000  Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %%
data.head(2)
# Out:
#   location  year    run    FUEL   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000     CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000  Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %%
# renaming multiple columns at one 
data.columns
# Out:
# Index(['location', 'year', 'run', 'FUEL', 'trans', 'owner', 'mileage',
#        'engine', 'power', 'seats', 'new_price', 'price', 'brand', 'model'],
#       dtype='object')

# %%
data.rename(columns= {'location':'place', 'year':'time','run':'kms'}, inplace=True)
data.head(2)
# Out:
#     place  time    kms    FUEL   trans  owner  mileage  engine   power  seats  \
# 0  Mumbai  2010  72000     CNG  Manual  First    26.60   998.0   58.16    5.0
# 1    Pune  2015  41000  Diesel  Manual  First    19.67  1582.0  126.20    5.0
#
#   new_price  price    brand  model
# 0       NaN   1.75   Maruti  Wagon
# 1       NaN  12.50  Hyundai  Creta

# %%
# dropping the columns
# single columns 
# multiple 
# specific data types

# %%
data.drop('new_price', axis=1, inplace=True) # drops a single column named 'new_price'

# %%
data.head(2)
# Out:
#     place  time    kms    FUEL   trans  owner  mileage  engine   power  seats  \
# 0  Mumbai  2010  72000     CNG  Manual  First    26.60   998.0   58.16    5.0
# 1    Pune  2015  41000  Diesel  Manual  First    19.67  1582.0  126.20    5.0
#
#    price    brand  model
# 0   1.75   Maruti  Wagon
# 1  12.50  Hyundai  Creta

# %%
# drop multiple columns 
data.drop(['brand','model', 'kms'],axis=1, inplace=True)

# %%
data.head(2)
# Out:
#     place  time    FUEL   trans  owner  mileage  engine   power  seats  price
# 0  Mumbai  2010     CNG  Manual  First    26.60   998.0   58.16    5.0   1.75
# 1    Pune  2015  Diesel  Manual  First    19.67  1582.0  126.20    5.0  12.50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   place    7253 non-null   object
#  1   time     7253 non-null   int64
#  2   FUEL     7253 non-null   object
#  3   trans    7253 non-null   object
#  4   owner    7253 non-null   object
#  5   mileage  7251 non-null   float64
#  6   engine   7207 non-null   float64
#  7   power    7078 non-null   float64
#  8   seats    7200 non-null   float64
#  9   price    6019 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 566.8+ KB

# %%
# Adding Columns

# %%
data = pd.read_csv(r"E:\python 1 pm\stats_for_data_analysis\cars_data_updated.csv") # load the data again
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model
# 0    5.0       NaN   1.75   Maruti  Wagon
# 1    5.0       NaN  12.50  Hyundai  Creta

# %%
# Add Calculated Columns 
# Create a colunmns that shows 10 % or price value of each car 
# sytnax 
data_frame[new_col_name] = expression

# %%
data['price'].isna().sum()
# Out:
# np.int64(1234)

# %%
data['new_price']*0.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Code it Python\venv\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File D:\Code it Python\venv\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File D:\Code it Python\venv\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# ...

# %%
data['mileage_10p'] = data['mileage'] * 0.1
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model  mileage_10p
# 0    5.0       NaN   1.75   Maruti  Wagon        2.660
# 1    5.0       NaN  12.50  Hyundai  Creta        1.967

# %%
# Create 10 % value of engine 
data['engine_new'] = data['engine'] *0.1
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model  mileage_10p  engine_new
# 0    5.0       NaN   1.75   Maruti  Wagon        2.660        99.8
# 1    5.0       NaN  12.50  Hyundai  Creta        1.967       158.2

# %%
# Create 10 % value of price 
data['new_price_value'] = data['price'] *0.1
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model  mileage_10p  engine_new  \
# 0    5.0       NaN   1.75   Maruti  Wagon        2.660        99.8
# 1    5.0       NaN  12.50  Hyundai  Creta        1.967       158.2
#
#    new_price_value
# 0            0.175
# 1            1.250

# %%
# Add Columns using functions 
# Create a mileage category 
data.mileage.agg(['min', 'max'])
# Out:
# min     0.00
# max    33.54
# Name: mileage, dtype: float64

# %%
def mileage_classify(value): 
    if value >=30:  # 30 above
        return "Very Good Mileage"
    elif value >=20:  # 20 - 29 
        return "Good Mileage"
    elif value >=10: # 
        return "Nice Mileage" 
    else: 
        return "Bad Mileage"

# %%
data['mileage'].apply(mileage_classify)
# Out:
# 0       Good Mileage
# 1       Nice Mileage
# 2       Nice Mileage
# 3       Good Mileage
# 4       Nice Mileage
#             ...
# 7248    Good Mileage
# 7249    Nice Mileage
# 7250    Good Mileage
# 7251    Nice Mileage
# 7252    Nice Mileage
# Name: mileage, Length: 7253, dtype: object

# %%
data['mileage class'] = data['mileage'].apply(mileage_classify)
data.head(2)
# Out:
#   location  year    run fuel_type   trans  owner  mileage  engine   power  \
# 0   Mumbai  2010  72000       CNG  Manual  First    26.60   998.0   58.16
# 1     Pune  2015  41000    Diesel  Manual  First    19.67  1582.0  126.20
#
#    seats new_price  price    brand  model  mileage_10p  engine_new  \
# 0    5.0       NaN   1.75   Maruti  Wagon        2.660        99.8
# 1    5.0       NaN  12.50  Hyundai  Creta        1.967       158.2
#
#    new_price_value mileage class
# 0            0.175  Good Mileage
# 1            1.250  Nice Mileage

# %%
data['mileage'] + data['power']
# Out:
# 0        84.76
# 1       145.87
# 2       106.90
# 3       109.53
# 4       156.00
#          ...
# 7248    124.14
# 7249    120.81
# 7250     86.18
# 7251    120.80
# 7252    180.00
# Length: 7253, dtype: float64

# %%
0-9 Bad Mileage
10-19 Nice Mileage 
20-29 Good Mileage
30 Above Very Good Mileage

# %%
# Drop all categorical values 
new_data = data.select_dtypes(['int64', 'float64'])

# %%
new_data
# Out:
#       time  mileage  engine   power  seats  price
# 0     2010    26.60   998.0   58.16    5.0   1.75
# 1     2015    19.67  1582.0  126.20    5.0  12.50
# 2     2011    18.20  1199.0   88.70    5.0   4.50
# 3     2012    20.77  1248.0   88.76    7.0   6.00
# 4     2013    15.20  1968.0  140.80    5.0  17.74
# ...    ...      ...     ...     ...    ...    ...
# 7248  2011    20.54  1598.0  103.60    5.0    NaN
# 7249  2015    17.21  1197.0  103.60    5.0    NaN
# 7250  2012    23.08  1461.0   63.10    5.0    NaN
# 7251  2013    17.20  1197.0  103.60    5.0    NaN
# 7252  2014    10.00  2148.0  170.00    5.0    NaN
#
# [7253 rows x 6 columns]

# %%
# Brand Maruti 
# fuel petrol 
# tansmission automatic

# %%
data.columns
# Out:
# Index(['place', 'time', 'FUEL', 'trans', 'owner', 'mileage', 'engine', 'power',
#        'seats', 'price'],
#       dtype='object')

# %%
data['power']
# Out:
# 0        58.16
# 1       126.20
# 2        88.70
# 3        88.76
# 4       140.80
#          ...
# 7248    103.60
# 7249    103.60
# 7250     63.10
# 7251    103.60
# 7252    170.00
# Name: power, Length: 7253, dtype: float64

# %%
data[['FUEL', 'trans', 'seats']]
# Out:
#         FUEL      trans  seats
# 0        CNG     Manual    5.0
# 1     Diesel     Manual    5.0
# 2     Petrol     Manual    5.0
# 3     Diesel     Manual    7.0
# 4     Diesel  Automatic    5.0
# ...      ...        ...    ...
# 7248  Diesel     Manual    5.0
# 7249  Petrol  Automatic    5.0
# 7250  Diesel     Manual    5.0
# 7251  Petrol  Automatic    5.0
# 7252  Diesel  Automatic    5.0
#
# [7253 rows x 3 columns]

# %%
# Handling missing data (fillna, dropna).
Renaming, adding, and dropping columns.
    Transforming and replacing data.

# %%
csv file 
when we load it 
        dataframe if any change.  save in dataframe (inplace=True) 
csv file 
export in to csv file (new version)

# %%
data / 
business probelm (

# %% [markdown]
# <h2> <b> Handling missing data (fillna, dropna). </b> </h2>

# %%
data.head()
# Out:
#      location  year    run fuel_type      trans   owner  mileage  engine  \
# 0      Mumbai  2010  72000       CNG     Manual   First    26.60   998.0
# 1        Pune  2015  41000    Diesel     Manual   First    19.67  1582.0
# 2     Chennai  2011  46000    Petrol     Manual   First    18.20  1199.0
# 3     Chennai  2012  87000    Diesel     Manual   First    20.77  1248.0
# 4  Coimbatore  2013  40670    Diesel  Automatic  Second    15.20  1968.0
#
#     power  seats  new_price  price    brand   model  mileage_10p  engine_new  \
# 0   58.16    5.0        NaN   1.75   Maruti   Wagon        2.660        99.8
# 1  126.20    5.0        NaN  12.50  Hyundai   Creta        1.967       158.2
# 2   88.70    5.0  8.61 Lakh   4.50    Honda    Jazz        1.820       119.9
# 3   88.76    7.0        NaN   6.00   Maruti  Ertiga        2.077       124.8
# 4  140.80    5.0        NaN  17.74     Audi      A4        1.520       196.8
#
#    new_price_value mileage class
# ...

# %%
# isna() , is used to find a null or missing values 
data.isna().sum()  # retrusn all 'NA' values in the dataset
# Out:
# location              0
# year                  0
# run                   0
# fuel_type             0
# trans                 0
# owner                 0
# mileage               2
# engine               46
# power               175
# seats                53
# new_price          6247
# price              1234
# brand                 0
# model                 0
# mileage_10p           2
# engine_new           46
# new_price_value    1234
# mileage class         0
# dtype: int64

# %%
# Handeling (missing and null) either drop, of fill 
# if values is missing is less than 5% (fill) / drop 
# if values > 5% mss drop 
# new_price nad prcie 
data.shape
# Out:
# (7253, 18)

# %%
data.drop(['new_price', 'price'], axis=1, inplace=True)

# %%
data.isna().sum()
# Out:
# location              0
# year                  0
# run                   0
# fuel_type             0
# trans                 0
# owner                 0
# mileage               2
# engine               46
# power               175
# seats                53
# brand                 0
# model                 0
# mileage_10p           2
# engine_new           46
# new_price_value    1234
# mileage class         0
# dtype: int64

# %%
data  = data[['brand', 'model', 'location', 'engine', 'power', 'mileage', 'seats']]

# %%
data.isna().sum()
# Out:
# brand         0
# model         0
# location      0
# engine       46
# power       175
# mileage       2
# seats        53
# dtype: int64

# %%
# delete all the rows with a single cell is 'NA' 
df = data.dropna()

# %%
df
# Out:
#               brand    model    location  engine   power  mileage  seats
# 0            Maruti    Wagon      Mumbai   998.0   58.16    26.60    5.0
# 1           Hyundai    Creta        Pune  1582.0  126.20    19.67    5.0
# 2             Honda     Jazz     Chennai  1199.0   88.70    18.20    5.0
# 3            Maruti   Ertiga     Chennai  1248.0   88.76    20.77    7.0
# 4              Audi       A4  Coimbatore  1968.0  140.80    15.20    5.0
# ...             ...      ...         ...     ...     ...      ...    ...
# 7248     Volkswagen    Vento   Hyderabad  1598.0  103.60    20.54    5.0
# 7249     Volkswagen     Polo      Mumbai  1197.0  103.60    17.21    5.0
# 7250         Nissan    Micra     Kolkata  1461.0   63.10    23.08    5.0
# 7251     Volkswagen     Polo        Pune  1197.0  103.60    17.20    5.0
# 7252  Mercedes-Benz  E-Class       Kochi  2148.0  170.00    10.00    5.0
#
# [7073 rows x 7 columns]

# %%
data.shape
# Out:
# (7253, 7)

# %%
df.shape
# Out:
# (7073, 7)

# %%
dropna()

# %%
data.shape
# Out:
# (7253, 7)

# %%
# fill na() 
# mode() 
# mean () 
# std() 
# bfill
# afterfill() 
Age: 
Rauthat 
1000 peopel 
20% - 15 200/1000 
30% 17 300/1000
45 % 20  450/1000  
5%= missing ()  20 , mean ,meadin

# %%
200/1000
# Out:
# 0.2

# %%
450/1000
# Out:
# 0.45

# %%
data.isna().sum()
# Out:
# brand         0
# model         0
# location      0
# engine       46
# power       175
# mileage       2
# seats        53
# dtype: int64

# %%
average_power = data['power'].mean()
average_power
# Out:
# np.float64(112.76521404351512)

# %%
data['power'] = data.power.fillna(average_power)

# %%
data['power'].isna().sum()
# Out:
# np.int64(0)

# %%
# temp {data } 
# model {} 
data. colder

# %%
machinelearnig 
data read 
predcit () 
model 
# model deployment { } 
# Data , coluder

# %%
# Roll {0-5} 
20 21 22 {50., 45}
